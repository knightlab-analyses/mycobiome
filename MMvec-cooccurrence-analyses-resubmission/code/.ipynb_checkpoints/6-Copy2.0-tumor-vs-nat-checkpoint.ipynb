# %%
import numpy as np
import pandas as pd
from biom import (load_table,
                  Table)
from qiime2 import (Artifact,
                    Metadata, Visualization)
from skbio import OrdinationResults, DistanceMatrix
from skbio.stats.distance import permanova
from qiime2.plugins.diversity.actions import beta, pcoa
from qiime2.plugins.gemelli.actions import rpca
from tqdm.notebook import tqdm
from scipy.spatial import ConvexHull

import colorsys
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mc
from matplotlib.pyplot import cm
from matplotlib.colors import to_hex
plt.style.use('seaborn') 

# %matplotlib inline

# %%
# import raw data
mf_df = pd.read_csv('../data/tumor_vs_nat/t_vs_nat_scaled_metadata_TCGA.csv', index_col=0)
mf_df = mf_df[mf_df.experimental_strategy == 'WGS']
tbl_df = pd.read_csv('../data/tumor_vs_nat/t_vs_nat_scaled_rel_abundances_TCGA.csv', index_col=0)
mf_df = mf_df.reindex(tbl_df.index)

mf_df.head(5)
# Out:
#                                              sample_name  \
# 13722.58cfa82de4b0c9d6adf6a4c2  58cfa82de4b0c9d6adf6a4c2
# 13722.58cfa82de4b0c9d6adf6a502  58cfa82de4b0c9d6adf6a502
# 13722.58cfa82de4b0c9d6adf6a4ce  58cfa82de4b0c9d6adf6a4ce
# 13722.58cfa82de4b0c9d6adf6a48a  58cfa82de4b0c9d6adf6a48a
# 13722.58cfa82de4b0c9d6adf6a4d4  58cfa82de4b0c9d6adf6a4d4
#
#                                                                 run_prefix  \
# 13722.58cfa82de4b0c9d6adf6a4c2  12dd02ea14d0a87df23ce3bef406fe27.filtered.
# 13722.58cfa82de4b0c9d6adf6a502  3d9f475186150ea055fddf25af7bb7e3.filtered.
# 13722.58cfa82de4b0c9d6adf6a4ce  2258e57e8e0af9db6969a1da86177ca7.filtered.
# 13722.58cfa82de4b0c9d6adf6a48a  142ba22e796cab1075278cd533a287c8.filtered.
# 13722.58cfa82de4b0c9d6adf6a4d4  406aecbc23505359850e57fbf05d5b67.filtered.
#
#                                experimental_strategy  \
# 13722.58cfa82de4b0c9d6adf6a4c2                   WGS
# 13722.58cfa82de4b0c9d6adf6a502                   WGS
# 13722.58cfa82de4b0c9d6adf6a4ce                   WGS
# 13722.58cfa82de4b0c9d6adf6a48a                   WGS
# 13722.58cfa82de4b0c9d6adf6a4d4                   WGS
#
#                                                    cgc_base_name  \
# 13722.58cfa82de4b0c9d6adf6a4c2  12dd02ea14d0a87df23ce3bef406fe27
# 13722.58cfa82de4b0c9d6adf6a502  3d9f475186150ea055fddf25af7bb7e3
# 13722.58cfa82de4b0c9d6adf6a4ce  2258e57e8e0af9db6969a1da86177ca7
# 13722.58cfa82de4b0c9d6adf6a48a  142ba22e796cab1075278cd533a287c8
# 13722.58cfa82de4b0c9d6adf6a4d4  406aecbc23505359850e57fbf05d5b67
#
#                                                             filename  \
# 13722.58cfa82de4b0c9d6adf6a4c2  12dd02ea14d0a87df23ce3bef406fe27.bam
# 13722.58cfa82de4b0c9d6adf6a502  3d9f475186150ea055fddf25af7bb7e3.bam
# 13722.58cfa82de4b0c9d6adf6a4ce  2258e57e8e0af9db6969a1da86177ca7.bam
# 13722.58cfa82de4b0c9d6adf6a48a  142ba22e796cab1075278cd533a287c8.bam
# 13722.58cfa82de4b0c9d6adf6a4d4  406aecbc23505359850e57fbf05d5b67.bam
#
#                                 analyte_amount  analyte_A260A280Ratio  \
# 13722.58cfa82de4b0c9d6adf6a4c2           32.75                    NaN
# 13722.58cfa82de4b0c9d6adf6a502           64.35                   1.70
# 13722.58cfa82de4b0c9d6adf6a4ce           62.02                   2.08
# 13722.58cfa82de4b0c9d6adf6a48a           93.54                   2.18
# 13722.58cfa82de4b0c9d6adf6a4d4           85.32                   1.85
#
#                                 aliquot_concentration  \
# 13722.58cfa82de4b0c9d6adf6a4c2                   0.08
# 13722.58cfa82de4b0c9d6adf6a502                   0.08
# 13722.58cfa82de4b0c9d6adf6a4ce                   0.08
# 13722.58cfa82de4b0c9d6adf6a48a                   0.07
# 13722.58cfa82de4b0c9d6adf6a4d4                   0.08
#
#                                                   cgc_id  \
# 13722.58cfa82de4b0c9d6adf6a4c2  58cfa82de4b0c9d6adf6a4c2
# 13722.58cfa82de4b0c9d6adf6a502  58cfa82de4b0c9d6adf6a502
# 13722.58cfa82de4b0c9d6adf6a4ce  58cfa82de4b0c9d6adf6a4ce
# 13722.58cfa82de4b0c9d6adf6a48a  58cfa82de4b0c9d6adf6a48a
# 13722.58cfa82de4b0c9d6adf6a4d4  58cfa82de4b0c9d6adf6a4d4
#
#                                                         cgc_filename  ...  \
# 13722.58cfa82de4b0c9d6adf6a4c2  12dd02ea14d0a87df23ce3bef406fe27.bam  ...
# 13722.58cfa82de4b0c9d6adf6a502  3d9f475186150ea055fddf25af7bb7e3.bam  ...
# 13722.58cfa82de4b0c9d6adf6a4ce  2258e57e8e0af9db6969a1da86177ca7.bam  ...
# 13722.58cfa82de4b0c9d6adf6a48a  142ba22e796cab1075278cd533a287c8.bam  ...
# 13722.58cfa82de4b0c9d6adf6a4d4  406aecbc23505359850e57fbf05d5b67.bam  ...
#
#                                     tissue_source_site_label  \
# 13722.58cfa82de4b0c9d6adf6a4c2                          Duke
# 13722.58cfa82de4b0c9d6adf6a502  University of North Carolina
# 13722.58cfa82de4b0c9d6adf6a4ce                         MSKCC
# 13722.58cfa82de4b0c9d6adf6a48a                         MSKCC
# 13722.58cfa82de4b0c9d6adf6a4d4                         MSKCC
#
#                                country_of_sample_procurement portion_is_ffpe  \
# 13722.58cfa82de4b0c9d6adf6a4c2                 United States              NO
# 13722.58cfa82de4b0c9d6adf6a502                 United States              NO
# 13722.58cfa82de4b0c9d6adf6a4ce                          None              NO
# 13722.58cfa82de4b0c9d6adf6a48a                          None              NO
# 13722.58cfa82de4b0c9d6adf6a4d4                          None              NO
#
#                                pathologic_t_label pathologic_n_label  \
# 13722.58cfa82de4b0c9d6adf6a4c2                 T2                 N0
# 13722.58cfa82de4b0c9d6adf6a502      Not available      Not available
# 13722.58cfa82de4b0c9d6adf6a4ce                 T3                 N2
# 13722.58cfa82de4b0c9d6adf6a48a      Not available      Not available
# 13722.58cfa82de4b0c9d6adf6a4d4      Not available      Not available
#
#                                            histological_diagnosis_label  \
# 13722.58cfa82de4b0c9d6adf6a4c2            Infiltrating Ductal Carcinoma
# 13722.58cfa82de4b0c9d6adf6a502  Endometrioid endometrial adenocarcinoma
# 13722.58cfa82de4b0c9d6adf6a4ce            Infiltrating Ductal Carcinoma
# 13722.58cfa82de4b0c9d6adf6a48a        Serous endometrial adenocarcinoma
# 13722.58cfa82de4b0c9d6adf6a4d4        Serous endometrial adenocarcinoma
#
#                                pathologic_stage_label PlateCenter  \
# 13722.58cfa82de4b0c9d6adf6a4c2              Stage IIA     A21Q-09
# 13722.58cfa82de4b0c9d6adf6a502          Not available     A13L-09
# 13722.58cfa82de4b0c9d6adf6a4ce             Stage IIIA     A19H-09
# 13722.58cfa82de4b0c9d6adf6a48a          Not available     A066-09
# 13722.58cfa82de4b0c9d6adf6a4d4          Not available     A066-09
#
#                                PlateCenterFlag  \
# 13722.58cfa82de4b0c9d6adf6a4c2            True
# 13722.58cfa82de4b0c9d6adf6a502           False
# 13722.58cfa82de4b0c9d6adf6a4ce            True
# 13722.58cfa82de4b0c9d6adf6a48a            True
# 13722.58cfa82de4b0c9d6adf6a4d4            True
#
#                                                 disease_and_sample_type
# 13722.58cfa82de4b0c9d6adf6a4c2             Breast Invasive Carcinoma PT
# 13722.58cfa82de4b0c9d6adf6a502  Uterine Corpus Endometrial Carcinoma PT
# 13722.58cfa82de4b0c9d6adf6a4ce             Breast Invasive Carcinoma PT
# 13722.58cfa82de4b0c9d6adf6a48a  Uterine Corpus Endometrial Carcinoma PT
# 13722.58cfa82de4b0c9d6adf6a4d4  Uterine Corpus Endometrial Carcinoma PT
#
# [5 rows x 42 columns]

# %% [markdown]
# # skip this section if already run

# %%
# import data in Q2
bt = Table(tbl_df.values.T, tbl_df.columns, tbl_df.index)
table = Artifact.import_data('FeatureTable[Frequency]', bt)

# beta div calculations
bc_dist = beta(table, 'braycurtis').distance_matrix
jc_dist = beta(table, 'jaccard').distance_matrix
bc_pcoa = pcoa(bc_dist).pcoa
jc_pcoa = pcoa(jc_dist).pcoa
atch_biplot, atch_dist = rpca(table)

# save dists
bc_dist.save('../results/beta-div/bc-dist.qza')
jc_dist.save('../results/beta-div/jc-dist.qza')
bc_pcoa.save('../results/beta-div/bc-pcoa.qza')
jc_pcoa.save('../results/beta-div/jc-pcoa.qza')
atch_biplot.save('../results/beta-div/aitch-biplot.qza')
atch_dist.save('../results/beta-div/aitch-dist.qza')
# Out:
# /home/cmartino/.conda/envs/qiime2-2019.7/lib/python3.6/site-packages/sklearn/metrics/pairwise.py:1575: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# /home/cmartino/.conda/envs/qiime2-2019.7/lib/python3.6/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:152: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -4.159800441090162 and the largest is 372.571715657325.
#   RuntimeWarning
# /home/cmartino/.conda/envs/qiime2-2019.7/lib/python3.6/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:152: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.006323589083495294 and the largest is 0.11392716863551453.
#   RuntimeWarning
# /home/cmartino/.conda/envs/qiime2-2019.7/lib/python3.6/site-packages/gemelli/preprocessing.py:155: RuntimeWarning: divide by zero encountered in log
#   M_log = np.log(M_log.squeeze())

# %% [markdown]
# # re-import from mem.

# %%
# save dists
bc_dist = Artifact.load('../results/beta-div/bc-dist.qza')
jc_dist = Artifact.load('../results/beta-div/jc-dist.qza')
bc_pcoa = Artifact.load('../results/beta-div/bc-pcoa.qza')
jc_pcoa = Artifact.load('../results/beta-div/jc-pcoa.qza')
atch_biplot = Artifact.load('../results/beta-div/aitch-biplot.qza')
atch_dist = Artifact.load('../results/beta-div/aitch-dist.qza')

# %%
# export distances
bc_dist_dm = bc_dist.view(DistanceMatrix)
jc_dist_dm = jc_dist.view(DistanceMatrix)
atch_dist_dm = atch_dist.view(DistanceMatrix)

# %%
# keep matched to WIS
keep_subset = ['Breast Invasive Carcinoma',
                 'Colon Adenocarcinoma',
                 'Lung Adenocarcinoma',
                 'Lung Squamous Cell Carcinoma',
                 'Ovarian Serous Cystadenocarcinoma',
                 'Rectum Adenocarcinoma']
# matched
mf_df_matched_groups = {k:{k2:df2
                           for k2, df2 in df.groupby(['tcga_case_id', 'data_submitting_center_label'])
                           if len(set(df2['sample_type'])) == 2}
                        for k, df in mf_df[mf_df.disease_type.isin(keep_subset)].groupby(['disease_type'])}
subjects_use = [v_i[0] for _, v in mf_df_matched_groups.items() for v_i in v]
mf_df_subset = mf_df[mf_df.tcga_case_id.isin(subjects_use)]

# store results
between_dist_results = {}
atch_dist_dm_df = pd.DataFrame(atch_dist_dm.data, atch_dist_dm.ids, atch_dist_dm.ids)
bc_dist_dm_df = pd.DataFrame(bc_dist_dm.data, bc_dist_dm.ids, bc_dist_dm.ids)
jc_dist_dm_df = pd.DataFrame(jc_dist_dm.data, jc_dist_dm.ids, jc_dist_dm.ids)
for metric_, dist_tmp in zip(['Bray-Curtis'],
                             [bc_dist_dm_df]):
    for ctype, sdict in tqdm(mf_df_matched_groups.items()):
        # get between all subjects in cancer type
        mf_tmp_within_dis = pd.concat(sdict.values())
        all_subjects_in_distype = list(mf_tmp_within_dis.index)
        # get all subjects outside this cancer type 
        """by_center_ = []
        for center_, tmp_type_df in mf_df[(mf_df.disease_type == ctype)].groupby('data_submitting_center_label'):
            all_others = mf_df[(mf_df.disease_type != ctype)
                               & (mf_df.data_submitting_center_label == center_)]
            bc_dist_dm_df_tmp_ = dist_tmp.loc[tmp_type_df.index,
                                              all_others.index].stack().reset_index()
            bc_dist_dm_df_tmp_.columns = ['s1', 's2', 'distance']
            bc_dist_dm_df_tmp_ = bc_dist_dm_df_tmp_[bc_dist_dm_df_tmp_.s1 != bc_dist_dm_df_tmp_.s2]   
            by_center_.append(bc_dist_dm_df_tmp_)
        bc_dist_dm_df_tmp = pd.concat(by_center_).copy()
        between_dist_results[(metric_, ctype, 'Between Cancer Type')] = bc_dist_dm_df_tmp.copy()"""
        # get dis type vs. other dis type
        bc_dist_dm_df_tmp = dist_tmp.loc[all_subject_outside_distype,
                                         all_subjects_in_distype].stack().reset_index()
        bc_dist_dm_df_tmp.columns = ['s1', 's2', 'distance']
        between_dist_results[(metric_, ctype, 'Between Cancer Type')] = bc_dist_dm_df_tmp
        
        # get all in dis type
        by_center_ = []
        for center_, tmp_type_df in mf_df[(mf_df.disease_type == ctype) 
                                          & (mf_df.sample_type == 'PT')].groupby('data_submitting_center_label'):
            within_index = sorted(tmp_type_df.index)
            bc_dist_dm_df_tmp_ = dist_tmp.loc[within_index[:1],
                                              within_index[1:]].stack().reset_index()
            bc_dist_dm_df_tmp_.columns = ['s1', 's2', 'distance']
            by_center_.append(bc_dist_dm_df_tmp_)
        bc_dist_dm_df_tmp = pd.concat(by_center_).copy()
        between_dist_results[(metric_, ctype, 'Within Cancer Type')] = bc_dist_dm_df_tmp.copy()
        
        
        by_center_ = []
        for center_, tmp_type_df in mf_df[(mf_df.disease_type == ctype) 
                                          & (mf_df.sample_type == 'NAT')].groupby('data_submitting_center_label'):
            within_index = sorted(tmp_type_df.index)
            if len(within_index) <=1:
                continue
            bc_dist_dm_df_tmp_ = dist_tmp.loc[within_index[:1],
                                              within_index[1:]].stack().reset_index()
            bc_dist_dm_df_tmp_.columns = ['s1', 's2', 'distance']
            by_center_.append(bc_dist_dm_df_tmp_)
        bc_dist_dm_df_tmp = pd.concat(by_center_).copy()
        between_dist_results[(metric_, ctype, 'Within Cancer Type (NAT)')] = bc_dist_dm_df_tmp.copy()
        
        # get all subject between NAT v. Tumor within dis type
        within_between_stype = []
        for s_, pair_df in sdict.items():
            bc_dist_dm_df_tmp = dist_tmp.loc[pair_df.index[[1]],
                                             pair_df.index[[0]]].stack().reset_index()
            bc_dist_dm_df_tmp.columns = ['s1', 's2', 'distance']
            within_between_stype.append(bc_dist_dm_df_tmp.copy())
        between_dist_results[(metric_, ctype, 'Within Subject (Tumor vs. NAT)')] = pd.concat(within_between_stype).copy()
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-db6d3e8d4867> in <module>
#      38         between_dist_results[(metric_, ctype, 'Between Cancer Type')] = bc_dist_dm_df_tmp.copy()"""
#      39         # get dis type vs. other dis type
# ---> 40         bc_dist_dm_df_tmp = dist_tmp.loc[all_subject_outside_distype,
#      41                                          all_subjects_in_distype].stack().reset_index()
#      42         bc_dist_dm_df_tmp.columns = ['s1', 's2', 'distance']
#
# NameError: name 'all_subject_outside_distype' is not defined

# %%
between_dist_results_df = pd.concat(between_dist_results)
between_dist_results_df.index.names = ['metric', 'disease-type', 'compare', 'dropme']
between_dist_results_df = between_dist_results_df.reset_index().drop('dropme', axis=1)
between_dist_results_df.head(4)
# Out:
#         metric               disease-type              compare  \
# 0  Bray-Curtis  Breast Invasive Carcinoma  Between Cancer Type
# 1  Bray-Curtis  Breast Invasive Carcinoma  Between Cancer Type
# 2  Bray-Curtis  Breast Invasive Carcinoma  Between Cancer Type
# 3  Bray-Curtis  Breast Invasive Carcinoma  Between Cancer Type
#
#                                s1                              s2  distance
# 0  13722.58cfa82fe4b0c9d6adf6b8b8  13722.58cfa82de4b0c9d6adf6a4b8  0.491812
# 1  13722.58cfa82fe4b0c9d6adf6b8b8  13722.58cfa82fe4b0c9d6adf6b8e0  0.501317
# 2  13722.58cfa82fe4b0c9d6adf6b8b8  13722.58cfa83ce4b0c9d6adf72ef8  0.485225
# 3  13722.58cfa82fe4b0c9d6adf6b8b8  13722.58cfa82de4b0c9d6adf6a67a  0.489564

# %%
from scipy import stats


label_map = {'BRCA':'Breast Invasive Carcinoma', 'COAD':'Colon Adenocarcinoma',
             'LUAD':'Lung Adenocarcinoma',
             'LUSC':'Lung Squamous Cell Carcinoma',
             'OV':'Ovarian Serous Cystadenocarcinoma',
             'READ':'Rectum Adenocarcinoma'}
stats_all = {}

pal_ = {'Within Subject (Tumor vs. NAT)':'lightgrey',
        'Within Cancer Type':'white',
        'Between Cancer Type':'#e41a1c'}
hue_ord_ = ['Within Subject (Tumor vs. NAT)',
            'Within Cancer Type',
            'Between Cancer Type']
label_map = {v:k for k, v in label_map.items()}
 
metric_ = 'Bray-Curtis'

print(metric_)

fig, ax1 = plt.subplots(1, 1, figsize=(9, 5), sharex=True)

# subset for plot
between_dist_results_df_plot = between_dist_results_df[between_dist_results_df.metric == metric_].copy()
convex_hull_results_df_plot = convex_hull_results_df[convex_hull_results_df.metric == metric_].copy()

between_dist_results_df_plot['disease-type'] = [label_map[x] for x in between_dist_results_df_plot['disease-type']]
convex_hull_results_df_plot['disease-type'] = [label_map[x] for x in convex_hull_results_df_plot['disease-type']]

order_ = between_dist_results_df_plot[between_dist_results_df_plot.compare == 'Between Cancer Type'].groupby('disease-type').mean().sort_values('distance').index

sns.boxplot(x='disease-type', y='distance', hue='compare',
            data=between_dist_results_df_plot, order=order_,
            ax=ax1, showfliers=True, hue_order=hue_ord_, palette=pal_)

ax1.set_ylabel('Beta-Diversity distance \n Bray-Curtis',
              fontsize=18,
              family = 'arial',
              weight='bold',
              color='black')

for ax in [ax1]:
    ax.grid(False)
    ax.set_facecolor('white')
    ax.set_axisbelow(True)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(True)
    ax.spines['bottom'].set_visible(False)
    ax.spines['top'].set_visible(False)
    for sp_i in ax.spines.values():
        sp_i.set_linewidth(3)
    for child in ax.get_children():
        if isinstance(child, matplotlib.spines.Spine):
            child.set_color('black')
    ax.tick_params(axis='y', colors='black', width=2, length=10)
    ax.tick_params(axis='x', colors='black', width=2, length=10)

    for tick in ax.get_xticklabels():
        tick.set_fontproperties('arial')
        tick.set_ha('right')
        tick.set_rotation(45)
        tick.set_weight("bold")
        tick.set_color("black")
        tick.set_fontsize(18)
    for tick in ax.get_yticklabels():
        tick.set_fontproperties('arial')
        tick.set_weight("bold")
        tick.set_color("black")
        tick.set_fontsize(14)
    ax.set_xlabel('',
                  fontsize=14,
                  family = 'arial',
                  weight='normal',
                  color='black')
    ax.legend_.remove()
    
    
yval = 'distance'
h = 0.01

for xi, lbl_ in enumerate(order_):

    df_stat = between_dist_results_df_plot[between_dist_results_df_plot['disease-type'] == lbl_].copy()

    # one
    x_ = df_stat[df_stat['compare'] == hue_ord_[0]][yval].values
    y_ = df_stat[df_stat['compare'] == hue_ord_[2]][yval].values
    stat_ = stats.mannwhitneyu(x_, y_)
    tstat_ = stat_.statistic
    p_ = stat_.pvalue * 3
    stats_all[(metric_, hue_ord_[0], hue_ord_[2], yval, lbl_)] = (tstat_, p_)
    # n.s.
    if p_ >= 0.05:
        p_ = 'n.s.'
    #*P < 0.05;
    elif p_ < 0.05 and p_ > 0.01:
        p_ = '*'
    #**P < 0.001;
    elif p_ < 0.01 and p_ > 0.001:
        p_ = '**'
    #***P < 0.0001
    elif p_ < 0.001:
        p_ = '***'
    y, col = np.max(y_) + .15, 'k'
    x1, x2 = xi - .25, xi + .25
    ax1.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
    ax1.text((x1+x2)*.5, y+h, p_, ha='center', va='bottom',
            color=col, weight='bold', fontsize=14)

    # two
    x_ = df_stat[df_stat['compare'] == hue_ord_[0]][yval].values
    y_ = df_stat[df_stat['compare'] == hue_ord_[1]][yval].values
    stat_ = stats.mannwhitneyu(x_, y_)
    tstat_ = stat_.statistic
    p_ = stat_.pvalue * 3
    stats_all[(metric_, hue_ord_[0], hue_ord_[1], yval, lbl_)] = (tstat_, p_)
    # n.s.
    if p_ >= 0.05:
        p_ = 'n.s.'
    #*P < 0.05;
    elif p_ < 0.05 and p_ > 0.01:
        p_ = '*'
    #**P < 0.001;
    elif p_ < 0.01 and p_ > 0.001:
        p_ = '**'
    #***P < 0.0001
    elif p_ < 0.001:
        p_ = '***'
    y, col = np.mean(y_) + np.std(y_) + .2, 'k'
    x1, x2 = xi - .25, xi + 0
    ax1.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
    ax1.text((x1+x2)*.5, y+h, p_, ha='center', va='bottom',
            color=col, weight='bold', fontsize=14)

    # three
    x_ = df_stat[df_stat['compare'] == hue_ord_[1]][yval].values
    y_ = df_stat[df_stat['compare'] == hue_ord_[2]][yval].values
    stat_ = stats.mannwhitneyu(x_, y_)
    tstat_ = stat_.statistic
    p_ = stat_.pvalue * 3
    stats_all[(metric_, hue_ord_[1], hue_ord_[2], yval, lbl_)] = (tstat_, p_)
    # n.s.
    if p_ >= 0.05:
        p_ = 'n.s.'
    #*P < 0.05;
    elif p_ < 0.05 and p_ > 0.01:
        p_ = '*'
    #**P < 0.001;
    elif p_ < 0.01 and p_ > 0.001:
        p_ = '**'
    #***P < 0.0001
    elif p_ < 0.001:
        p_ = '***'
    y, col = np.max(y_), 'k'
    x1, x2 = xi + 0 , xi + 0.25
    ax1.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
    ax1.text((x1+x2)*.5, y+h, p_, ha='center', va='bottom',
            color=col, weight='bold', fontsize=14)

#if metric_ == 'Bray-Curtis':
#    ax1.set_ylim(0, 1)
#else:
#    ax1.set_ylim(0, 6)
#    todo=0

ax1.set_ylim(0, 1)

plt.tight_layout()

handles, labels = ax1.get_legend_handles_labels()
legend = ax.legend(handles[:], [l.replace('(','\n(') for l in labels[:]], loc=2, 
                         bbox_to_anchor=(1.0, 0.8),
                         prop={'size':14, 'weight':'bold'},
                         fancybox=False, framealpha=.0,
                         ncol=1, markerscale=.5)

plt.savefig('../results/figures/beta-div/%s-between-sample-type-subset-beta-only.pdf' % (metric_), 
        dpi=600, 
        bbox_inches='tight',
        facecolor=fig.get_facecolor(), 
        edgecolor='none')
plt.savefig('../results/figures/beta-div/%s-between-sample-type-subset-beta-only.svg' % (metric_), 
        dpi=600, 
        bbox_inches='tight',
        facecolor=fig.get_facecolor(), 
        edgecolor='none')
plt.show()
# Out:
# Bray-Curtis

# %%
from scipy import stats


label_map = {'BRCA':'Breast Invasive Carcinoma', 'COAD':'Colon Adenocarcinoma',
             'LUAD':'Lung Adenocarcinoma',
             'LUSC':'Lung Squamous Cell Carcinoma',
             'OV':'Ovarian Serous Cystadenocarcinoma',
             'READ':'Rectum Adenocarcinoma'}
stats_all = {}

pal_ = {'Within Subject (Tumor vs. NAT)':'lightgrey',
        'Within Cancer Type':'darkblue',
        'Within Cancer Type (NAT)':'white',
        'Between Cancer Type':'#e41a1c'}
hue_ord_ = ['Within Subject (Tumor vs. NAT)',
            'Within Cancer Type (NAT)',
            'Within Cancer Type',
            'Between Cancer Type']
label_map = {v:k for k, v in label_map.items()}
 
metric_ = 'Bray-Curtis'

print(metric_)

fig, ax1 = plt.subplots(1, 1, figsize=(9, 5), sharex=True)

# subset for plot
between_dist_results_df_plot = between_dist_results_df[between_dist_results_df.metric == metric_].copy()
convex_hull_results_df_plot = convex_hull_results_df[convex_hull_results_df.metric == metric_].copy()

between_dist_results_df_plot['disease-type'] = [label_map[x] for x in between_dist_results_df_plot['disease-type']]
convex_hull_results_df_plot['disease-type'] = [label_map[x] for x in convex_hull_results_df_plot['disease-type']]

order_ = between_dist_results_df_plot[between_dist_results_df_plot.compare == 'Between Cancer Type'].groupby('disease-type').mean().sort_values('distance').index

sns.boxplot(x='disease-type', y='distance', hue='compare',
            data=between_dist_results_df_plot, order=order_,
            ax=ax1, showfliers=True, hue_order=hue_ord_, palette=pal_)

ax1.set_ylabel('Beta-Diversity distance \n Bray-Curtis',
              fontsize=18,
              family = 'arial',
              weight='bold',
              color='black')

for ax in [ax1]:
    ax.grid(False)
    ax.set_facecolor('white')
    ax.set_axisbelow(True)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(True)
    ax.spines['bottom'].set_visible(False)
    ax.spines['top'].set_visible(False)
    for sp_i in ax.spines.values():
        sp_i.set_linewidth(3)
    for child in ax.get_children():
        if isinstance(child, matplotlib.spines.Spine):
            child.set_color('black')
    ax.tick_params(axis='y', colors='black', width=2, length=10)
    ax.tick_params(axis='x', colors='black', width=2, length=10)

    for tick in ax.get_xticklabels():
        tick.set_fontproperties('arial')
        tick.set_ha('right')
        tick.set_rotation(45)
        tick.set_weight("bold")
        tick.set_color("black")
        tick.set_fontsize(18)
    for tick in ax.get_yticklabels():
        tick.set_fontproperties('arial')
        tick.set_weight("bold")
        tick.set_color("black")
        tick.set_fontsize(14)
    ax.set_xlabel('',
                  fontsize=14,
                  family = 'arial',
                  weight='normal',
                  color='black')
    ax.legend_.remove()
    
    
"""yval = 'distance'
h = 0.01

for xi, lbl_ in enumerate(order_):

    df_stat = between_dist_results_df_plot[between_dist_results_df_plot['disease-type'] == lbl_].copy()

    # one
    x_ = df_stat[df_stat['compare'] == hue_ord_[0]][yval].values
    y_ = df_stat[df_stat['compare'] == hue_ord_[2]][yval].values
    stat_ = stats.mannwhitneyu(x_, y_)
    tstat_ = stat_.statistic
    p_ = stat_.pvalue * 3
    stats_all[(metric_, hue_ord_[0], hue_ord_[2], yval, lbl_)] = (tstat_, p_)
    # n.s.
    if p_ >= 0.05:
        p_ = 'n.s.'
    #*P < 0.05;
    elif p_ < 0.05 and p_ > 0.01:
        p_ = '*'
    #**P < 0.001;
    elif p_ < 0.01 and p_ > 0.001:
        p_ = '**'
    #***P < 0.0001
    elif p_ < 0.001:
        p_ = '***'
    y, col = np.max(y_) + .15, 'k'
    x1, x2 = xi - .25, xi + .25
    ax1.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
    ax1.text((x1+x2)*.5, y+h, p_, ha='center', va='bottom',
            color=col, weight='bold', fontsize=14)

    # two
    x_ = df_stat[df_stat['compare'] == hue_ord_[1]][yval].values
    y_ = df_stat[df_stat['compare'] == hue_ord_[3]][yval].values
    stat_ = stats.mannwhitneyu(x_, y_)
    tstat_ = stat_.statistic
    p_ = stat_.pvalue * 3
    stats_all[(metric_, hue_ord_[0], hue_ord_[1], yval, lbl_)] = (tstat_, p_)
    # n.s.
    if p_ >= 0.05:
        p_ = 'n.s.'
    #*P < 0.05;
    elif p_ < 0.05 and p_ > 0.01:
        p_ = '*'
    #**P < 0.001;
    elif p_ < 0.01 and p_ > 0.001:
        p_ = '**'
    #***P < 0.0001
    elif p_ < 0.001:
        p_ = '***'
    y, col = np.mean(y_) + np.std(y_) + .2, 'k'
    x1, x2 = xi - .25, xi + 0
    ax1.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
    ax1.text((x1+x2)*.5, y+h, p_, ha='center', va='bottom',
            color=col, weight='bold', fontsize=14)

    # three
    x_ = df_stat[df_stat['compare'] == hue_ord_[2]][yval].values
    y_ = df_stat[df_stat['compare'] == hue_ord_[3]][yval].values
    stat_ = stats.mannwhitneyu(x_, y_)
    tstat_ = stat_.statistic
    p_ = stat_.pvalue * 3
    stats_all[(metric_, hue_ord_[1], hue_ord_[2], yval, lbl_)] = (tstat_, p_)
    # n.s.
    if p_ >= 0.05:
        p_ = 'n.s.'
    #*P < 0.05;
    elif p_ < 0.05 and p_ > 0.01:
        p_ = '*'
    #**P < 0.001;
    elif p_ < 0.01 and p_ > 0.001:
        p_ = '**'
    #***P < 0.0001
    elif p_ < 0.001:
        p_ = '***'
    y, col = np.max(y_), 'k'
    x1, x2 = xi + 0 , xi + 0.25
    ax1.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
    ax1.text((x1+x2)*.5, y+h, p_, ha='center', va='bottom',
            color=col, weight='bold', fontsize=14)"""

#if metric_ == 'Bray-Curtis':
#    ax1.set_ylim(0, 1)
#else:
#    ax1.set_ylim(0, 6)
#    todo=0

ax1.set_ylim(0, 1)

plt.tight_layout()

handles, labels = ax1.get_legend_handles_labels()
legend = ax.legend(handles[:], [l.replace('(','\n(') for l in labels[:]], loc=2, 
                         bbox_to_anchor=(1.0, 0.8),
                         prop={'size':14, 'weight':'bold'},
                         fancybox=False, framealpha=.0,
                         ncol=1, markerscale=.5)

plt.savefig('../results/figures/beta-div/%s-between-sample-type-subset-beta-only.pdf' % (metric_), 
        dpi=600, 
        bbox_inches='tight',
        facecolor=fig.get_facecolor(), 
        edgecolor='none')
plt.savefig('../results/figures/beta-div/%s-between-sample-type-subset-beta-only.svg' % (metric_), 
        dpi=600, 
        bbox_inches='tight',
        facecolor=fig.get_facecolor(), 
        edgecolor='none')
plt.show()
# Out:
# Bray-Curtis

# %%
# get ordinations
convex_hull_results = {}
atch_biplot_ord = atch_biplot.view(OrdinationResults)
bc_pcoa_ord = bc_pcoa.view(OrdinationResults)

for metric_, ord_tmp in zip(['Aitchison', 'Bray-Curtis'],
                             [atch_biplot_ord, bc_pcoa_ord]):
    ord_tmp_df = ord_tmp.samples.copy()
    for ctype, sdict in tqdm(mf_df_matched_groups.items()):
        # get between all subjects in cancer type
        mf_tmp_within_dis = pd.concat(sdict.values())
        all_subjects_in_distype = list(mf_tmp_within_dis.index)
        # get covex hull vs. other dis types
        ch_all_between_types = []
        for other_distype in mf_df_matched_groups.keys():
            if other_distype == ctype:
                continue
            else:
                # get all subjects outside this cancer type 
                all_subject_outside_distype = list(pd.concat([v1 for v1 in mf_df_matched_groups[other_distype].values()]).index)
                # hull
                ch = ConvexHull(ord_tmp_df.loc[set(all_subjects_in_distype + all_subject_outside_distype), :].values[:, :3])
                ch_all_between_types.append([ch.volume, ch.area])
                #break
        ch_all_between_types = pd.DataFrame(ch_all_between_types)
        ch_all_between_types.columns = ['volume', 'area']
        convex_hull_results[(metric_, ctype, 'Between Cancer Type & All Other Types')] = ch_all_between_types
        # get ovex hull Tumor vs. NAT
        ch_within_between_stype = []
        for leavout in sdict.keys():
            keep_loo = pd.concat([v for k, v in sdict.items() if k != leavout])
            ch = ConvexHull(ord_tmp_df.loc[keep_loo.index, :].values[:, :3])
            ch_within_between_stype.append([ch.volume, ch.area])
        ch_within_between_stype = pd.DataFrame(ch_within_between_stype)
        ch_within_between_stype.columns = ['volume', 'area']
        convex_hull_results[(metric_, ctype, 'Within Cancer Type Tumor vs. NAT')] = ch_within_between_stype
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
convex_hull_results_df = pd.concat(convex_hull_results)
convex_hull_results_df.index.names = ['metric', 'disease-type', 'compare', 'dropme']
convex_hull_results_df = convex_hull_results_df.reset_index().drop('dropme', axis=1)
convex_hull_results_df.head(4)
# Out:
#       metric               disease-type  \
# 0  Aitchison  Breast Invasive Carcinoma
# 1  Aitchison  Breast Invasive Carcinoma
# 2  Aitchison  Breast Invasive Carcinoma
# 3  Aitchison  Breast Invasive Carcinoma
#
#                                  compare        volume      area
# 0  Between Cancer Type & All Other Types  2.939621e-06  0.001406
# 1  Between Cancer Type & All Other Types  5.228491e-06  0.002044
# 2  Between Cancer Type & All Other Types  7.423676e-07  0.000590
# 3  Between Cancer Type & All Other Types  5.123467e-07  0.000449

# %%
from scipy import stats


label_map = {'BRCA':'Breast Invasive Carcinoma', 'COAD':'Colon Adenocarcinoma',
             'LUAD':'Lung Adenocarcinoma',
             'LUSC':'Lung Squamous Cell Carcinoma',
             'OV':'Ovarian Serous Cystadenocarcinoma',
             'READ':'Rectum Adenocarcinoma'}
stats_all = {}

pal_ = {'Within Cancer Type Tumor vs. NAT':'lightgrey','Between Cancer Type & All Other Types':'#e41a1c'}
hue_ord_ = ['Within Cancer Type Tumor vs. NAT', 'Between Cancer Type & All Other Types']
label_map = {v:k for k, v in label_map.items()}

for metric_ in ['Aitchison', 'Bray-Curtis']:

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5), sharex=True)

    # subset for plot
    between_dist_results_df_plot = between_dist_results_df[between_dist_results_df.metric == metric_].copy()
    convex_hull_results_df_plot = convex_hull_results_df[convex_hull_results_df.metric == metric_].copy()

    between_dist_results_df_plot['disease-type'] = [label_map[x] for x in between_dist_results_df_plot['disease-type']]
    convex_hull_results_df_plot['disease-type'] = [label_map[x] for x in convex_hull_results_df_plot['disease-type']]

    order_ = between_dist_results_df_plot[between_dist_results_df_plot.compare == 'Between Cancer Type & All Other Types'].groupby('disease-type').mean().sort_values('distance').index

    sns.boxplot(x='disease-type', y='distance', hue='compare',
                data=between_dist_results_df_plot, order=order_,
                ax=ax1, showfliers=True, hue_order=hue_ord_, palette=pal_)
    sns.boxplot(x='disease-type', y='volume', hue='compare',
                data=convex_hull_results_df_plot, order=order_,
                ax=ax2, showfliers=True, hue_order=hue_ord_, palette=pal_)

    ax1.set_ylabel('Beta-Diversity Distances',
                  fontsize=18,
                  family = 'arial',
                  weight='bold',
                  color='black')
    ax2.set_ylabel('Convex Hull (volume)',
                  fontsize=18,
                  family = 'arial',
                  weight='bold',
                  color='black')
    for ax in [ax1, ax2]:
        ax.grid(False)
        ax.set_facecolor('white')
        ax.set_axisbelow(True)
        ax.spines['right'].set_visible(False)
        ax.spines['left'].set_visible(True)
        ax.spines['bottom'].set_visible(False)
        ax.spines['top'].set_visible(False)
        for sp_i in ax.spines.values():
            sp_i.set_linewidth(3)
        for child in ax.get_children():
            if isinstance(child, matplotlib.spines.Spine):
                child.set_color('black')
        ax.tick_params(axis='y', colors='black', width=2, length=10)
        ax.tick_params(axis='x', colors='black', width=2, length=10)

        for tick in ax.get_xticklabels():
            tick.set_fontproperties('arial')
            tick.set_ha('right')
            tick.set_rotation(45)
            tick.set_weight("bold")
            tick.set_color("black")
            tick.set_fontsize(18)
        for tick in ax.get_yticklabels():
            tick.set_fontproperties('arial')
            tick.set_weight("bold")
            tick.set_color("black")
            tick.set_fontsize(14)
        ax.set_xlabel('',
                      fontsize=14,
                      family = 'arial',
                      weight='normal',
                      color='black')
        ax.legend_.remove()

    for ax, df_stat, yval, h in zip([ax1, ax2],
                           [between_dist_results_df_plot,
                            convex_hull_results_df_plot],
                           ['distance', 'volume'], [0, 0]):

        for xi, lbl_ in enumerate(order_):


            x_ = df_stat[df_stat['compare'] == hue_ord_[0]][yval].values
            y_ = df_stat[df_stat['compare'] == hue_ord_[1]][yval].values
            stat_ = stats.mannwhitneyu(x_, y_)
            stats_all[(metric_, yval, lbl_)] = stat_
            p_ = stat_.pvalue

            # n.s.
            if p_ >= 0.05:
                p_ = ''
            #*P < 0.05;
            elif p_ < 0.05 and p_ > 0.01:
                p_ = '*'
            #**P < 0.001;
            elif p_ < 0.01 and p_ > 0.001:
                p_ = '**'
            #***P < 0.0001
            elif p_ < 0.001:
                p_ = '***'
            y, col = np.max(y_), 'k'
            x1, x2 = xi - .2, xi + .2
            ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
            ax.text((x1+x2)*.5, y+h, p_, ha='center', va='bottom',
                    color=col, weight='bold', fontsize=14)

    if metric_ == 'Bray-Curtis':
        ax1.set_ylim(0, 0.8)
        ax2.set_ylim(0, 0.005)
    elif metric_ == 'Aitchison':
        ax1.set_ylim(0, 4.5)
        ax2.set_ylim(0, 7e-6)
    else:
        todo=0

    plt.tight_layout()
    
    handles, labels = ax1.get_legend_handles_labels()
    legend = ax.legend(handles[:], labels[:], loc=2, 
                             bbox_to_anchor=(-1.4, 1.2),
                             prop={'size':14, 'weight':'bold'},
                             fancybox=False, framealpha=.0,
                             ncol=2, markerscale=.5)
    
    plt.savefig('../results/figures/beta-div/%s-between-sample-type-subset.pdf' % (metric_), 
            dpi=600, 
            bbox_inches='tight',
            facecolor=fig.get_facecolor(), 
            edgecolor='none')
    plt.savefig('../results/figures/beta-div/%s-between-sample-type-subset.svg' % (metric_), 
            dpi=600, 
            bbox_inches='tight',
            facecolor=fig.get_facecolor(), 
            edgecolor='none')
    plt.show()
# Out:
# findfont: Font family ['arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['arial'] not found. Falling back to DejaVu Sans.

# %%
from scipy import stats


label_map = {'BRCA':'Breast Invasive Carcinoma', 'COAD':'Colon Adenocarcinoma',
             'LUAD':'Lung Adenocarcinoma',
             'LUSC':'Lung Squamous Cell Carcinoma',
             'OV':'Ovarian Serous Cystadenocarcinoma',
             'READ':'Rectum Adenocarcinoma'}
stats_all = {}

pal_ = {'Within Cancer Type Tumor vs. NAT':'lightgrey','Between Cancer Type & All Other Types':'#e41a1c'}
hue_ord_ = ['Within Cancer Type Tumor vs. NAT', 'Between Cancer Type & All Other Types']
label_map = {v:k for k, v in label_map.items()}

for metric_ in ['Aitchison', 'Bray-Curtis']:

    fig, ax2 = plt.subplots(1, 1, figsize=(5.5, 5), sharex=True)

    # subset for plot
    between_dist_results_df_plot = between_dist_results_df[between_dist_results_df.metric == metric_].copy()
    convex_hull_results_df_plot = convex_hull_results_df[convex_hull_results_df.metric == metric_].copy()

    between_dist_results_df_plot['disease-type'] = [label_map[x] for x in between_dist_results_df_plot['disease-type']]
    convex_hull_results_df_plot['disease-type'] = [label_map[x] for x in convex_hull_results_df_plot['disease-type']]

    order_ = between_dist_results_df_plot[between_dist_results_df_plot.compare == 'Between Cancer Type & All Other Types'].groupby('disease-type').mean().sort_values('distance').index

    sns.boxplot(x='disease-type', y='volume', hue='compare',
                data=convex_hull_results_df_plot, order=order_,
                ax=ax2, showfliers=True, hue_order=hue_ord_, palette=pal_)

    ax2.set_ylabel('Convex Hull (volume)',
                  fontsize=18,
                  family = 'arial',
                  weight='bold',
                  color='black')
    for ax in [ax2]:
        ax.grid(False)
        ax.set_facecolor('white')
        ax.set_axisbelow(True)
        ax.spines['right'].set_visible(False)
        ax.spines['left'].set_visible(True)
        ax.spines['bottom'].set_visible(False)
        ax.spines['top'].set_visible(False)
        for sp_i in ax.spines.values():
            sp_i.set_linewidth(3)
        for child in ax.get_children():
            if isinstance(child, matplotlib.spines.Spine):
                child.set_color('black')
        ax.tick_params(axis='y', colors='black', width=2, length=10)
        ax.tick_params(axis='x', colors='black', width=2, length=10)

        for tick in ax.get_xticklabels():
            tick.set_fontproperties('arial')
            tick.set_ha('right')
            tick.set_rotation(45)
            tick.set_weight("bold")
            tick.set_color("black")
            tick.set_fontsize(18)
        for tick in ax.get_yticklabels():
            tick.set_fontproperties('arial')
            tick.set_weight("bold")
            tick.set_color("black")
            tick.set_fontsize(14)
        ax.set_xlabel('',
                      fontsize=14,
                      family = 'arial',
                      weight='normal',
                      color='black')
        ax.legend_.remove()

    for ax, df_stat, yval, h in zip([ax2],
                           [convex_hull_results_df_plot],
                           ['volume'], [0, 0]):

        for xi, lbl_ in enumerate(order_):


            x_ = df_stat[df_stat['compare'] == hue_ord_[0]][yval].values
            y_ = df_stat[df_stat['compare'] == hue_ord_[1]][yval].values
            stat_ = stats.mannwhitneyu(x_, y_)
            stats_all[(metric_, yval, lbl_)] = stat_
            p_ = stat_.pvalue

            # n.s.
            if p_ >= 0.05:
                p_ = ''
            #*P < 0.05;
            elif p_ < 0.05 and p_ > 0.01:
                p_ = '*'
            #**P < 0.001;
            elif p_ < 0.01 and p_ > 0.001:
                p_ = '**'
            #***P < 0.0001
            elif p_ < 0.001:
                p_ = '***'
            y, col = np.max(y_), 'k'
            x1, x2 = xi - .2, xi + .2
            ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
            ax.text((x1+x2)*.5, y+h, p_, ha='center', va='bottom',
                    color=col, weight='bold', fontsize=14)

    if metric_ == 'Bray-Curtis':
        ax2.set_ylim(0, 0.005)
    else:
        ax2.set_ylim(0, 7e-6)
        todo=0

    plt.tight_layout()
    
    handles, labels = ax2.get_legend_handles_labels()
    legend = ax.legend(handles[:], labels[:], loc=2, 
                             bbox_to_anchor=(-0.2, 1.3),
                             prop={'size':14, 'weight':'bold'},
                             fancybox=False, framealpha=.0,
                             ncol=1, markerscale=.5)
    
    plt.savefig('../results/figures/beta-div/%s-between-sample-type-subset-hull-only.pdf' % (metric_), 
            dpi=600, 
            bbox_inches='tight',
            facecolor=fig.get_facecolor(), 
            edgecolor='none')
    plt.savefig('../results/figures/beta-div/%s-between-sample-type-subset-hull-only.svg' % (metric_), 
            dpi=600, 
            bbox_inches='tight',
            facecolor=fig.get_facecolor(), 
            edgecolor='none')
    plt.show()

# %% [markdown]
# # permanova

# %%
# store results
permanova_results = {}
for dt_tmp, mf_tmp in tqdm(mf_df.groupby('disease_type')):
    if len(set(mf_tmp.sample_type)) != 2:
        continue
    # ensure matched / subset
    shared_ = set(mf_tmp.index) & set(bc_dist_dm.ids) & set(jc_dist_dm.ids) & set(atch_dist_dm.ids)
    bc_dist_dm_tmp = bc_dist_dm.copy().filter(shared_)
    jc_dist_dm_tmp = jc_dist_dm.copy().filter(shared_)
    atch_dist_dm_tmp = atch_dist_dm.copy().filter(shared_)
    # permanova within type across sample_type
    permanova_results[(dt_tmp, 'Bray-Curtis')] = permanova(bc_dist_dm_tmp,
                                                           mf_tmp['sample_type'])
    permanova_results[(dt_tmp, 'Aitchison')] = permanova(atch_dist_dm_tmp,
                                                         mf_tmp['sample_type'])
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]

# %%
# generate PERMANOVA results
permanova_results_df = pd.DataFrame(permanova_results).T
permanova_results_df.index.names = ['disease-type', 'metric']
permanova_results_df['q-value'] = permanova_results_df['p-value'] * len(set([x[0] for x in permanova_results_df.index]))
permanova_results_df.loc[permanova_results_df['q-value'] > 1, 'q-value'] = 1
permanova_results_df = permanova_results_df.loc[(slice(None), ['Bray-Curtis', 'Aitchison']), :]
permanova_results_df.to_csv('../results/beta-div/permaniva-res-sample-type.csv')
permanova_results_df.to_csv('../results/tables/beta-div/permaniva-res-sample-type.csv')
permanova_results_df.head(10)
# Out:
#                                                                method name  \
# disease-type                                       metric
# Bladder Urothelial Carcinoma                       Bray-Curtis   PERMANOVA
#                                                    Aitchison     PERMANOVA
# Breast Invasive Carcinoma                          Bray-Curtis   PERMANOVA
#                                                    Aitchison     PERMANOVA
# Cervical Squamous Cell Carcinoma and Endocervic... Bray-Curtis   PERMANOVA
#                                                    Aitchison     PERMANOVA
# Cholangiocarcinoma                                 Bray-Curtis   PERMANOVA
#                                                    Aitchison     PERMANOVA
# Colon Adenocarcinoma                               Bray-Curtis   PERMANOVA
#                                                    Aitchison     PERMANOVA
#
#                                                                test statistic name  \
# disease-type                                       metric
# Bladder Urothelial Carcinoma                       Bray-Curtis            pseudo-F
#                                                    Aitchison              pseudo-F
# Breast Invasive Carcinoma                          Bray-Curtis            pseudo-F
#                                                    Aitchison              pseudo-F
# Cervical Squamous Cell Carcinoma and Endocervic... Bray-Curtis            pseudo-F
#                                                    Aitchison              pseudo-F
# Cholangiocarcinoma                                 Bray-Curtis            pseudo-F
#                                                    Aitchison              pseudo-F
# Colon Adenocarcinoma                               Bray-Curtis            pseudo-F
#                                                    Aitchison              pseudo-F
#
#                                                                sample size  \
# disease-type                                       metric
# Bladder Urothelial Carcinoma                       Bray-Curtis         580
#                                                    Aitchison           580
# Breast Invasive Carcinoma                          Bray-Curtis        1251
#                                                    Aitchison          1251
# Cervical Squamous Cell Carcinoma and Endocervic... Bray-Curtis         364
#                                                    Aitchison           364
# Cholangiocarcinoma                                 Bray-Curtis          41
#                                                    Aitchison            41
# Colon Adenocarcinoma                               Bray-Curtis         465
#                                                    Aitchison           465
#
#                                                                number of groups  \
# disease-type                                       metric
# Bladder Urothelial Carcinoma                       Bray-Curtis                2
#                                                    Aitchison                  2
# Breast Invasive Carcinoma                          Bray-Curtis                2
#                                                    Aitchison                  2
# Cervical Squamous Cell Carcinoma and Endocervic... Bray-Curtis                2
#                                                    Aitchison                  2
# Cholangiocarcinoma                                 Bray-Curtis                2
#                                                    Aitchison                  2
# Colon Adenocarcinoma                               Bray-Curtis                2
#                                                    Aitchison                  2
#
#                                                                test statistic  \
# disease-type                                       metric
# Bladder Urothelial Carcinoma                       Bray-Curtis       0.327685
#                                                    Aitchison          1.12574
# Breast Invasive Carcinoma                          Bray-Curtis        1.18617
#                                                    Aitchison         0.646303
# Cervical Squamous Cell Carcinoma and Endocervic... Bray-Curtis       0.703561
#                                                    Aitchison         0.462456
# Cholangiocarcinoma                                 Bray-Curtis       0.576654
#                                                    Aitchison         0.712842
# Colon Adenocarcinoma                               Bray-Curtis       0.962549
#                                                    Aitchison          1.68812
#
#                                                                p-value  \
# disease-type                                       metric
# Bladder Urothelial Carcinoma                       Bray-Curtis   0.971
#                                                    Aitchison     0.298
# Breast Invasive Carcinoma                          Bray-Curtis   0.303
#                                                    Aitchison     0.523
# Cervical Squamous Cell Carcinoma and Endocervic... Bray-Curtis   0.627
#                                                    Aitchison     0.603
# Cholangiocarcinoma                                 Bray-Curtis   0.682
#                                                    Aitchison     0.466
# Colon Adenocarcinoma                               Bray-Curtis   0.411
#                                                    Aitchison     0.169
#
#                                                                number of permutations  \
# disease-type                                       metric
# Bladder Urothelial Carcinoma                       Bray-Curtis                    999
#                                                    Aitchison                      999
# Breast Invasive Carcinoma                          Bray-Curtis                    999
#                                                    Aitchison                      999
# Cervical Squamous Cell Carcinoma and Endocervic... Bray-Curtis                    999
#                                                    Aitchison                      999
# Cholangiocarcinoma                                 Bray-Curtis                    999
#                                                    Aitchison                      999
# Colon Adenocarcinoma                               Bray-Curtis                    999
#                                                    Aitchison                      999
#
#                                                                q-value
# disease-type                                       metric
# Bladder Urothelial Carcinoma                       Bray-Curtis       1
#                                                    Aitchison         1
# Breast Invasive Carcinoma                          Bray-Curtis       1
#                                                    Aitchison         1
# Cervical Squamous Cell Carcinoma and Endocervic... Bray-Curtis       1
#                                                    Aitchison         1
# Cholangiocarcinoma                                 Bray-Curtis       1
#                                                    Aitchison         1
# Colon Adenocarcinoma                               Bray-Curtis       1
#                                                    Aitchison         1
